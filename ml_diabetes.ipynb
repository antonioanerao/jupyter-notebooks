# %%
import pandas as pd
from sklearn.datasets import load_diabetes
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import train_test_split

# %%
diabetes = load_diabetes()

# %%
print(diabetes)
# Out:
# {'data': array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#          0.01990749, -0.01764613],
#        [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#         -0.06833155, -0.09220405],
#        [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#          0.00286131, -0.02593034],
#        ...,
#        [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#         -0.04688253,  0.01549073],
#        [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#          0.04452873, -0.02593034],
#        [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#         -0.00422151,  0.00306441]]), 'target': array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#         69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#         68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#         87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
# ...

# %%
df = pd.DataFrame(diabetes.data, columns=diabetes.feature_names).head()
print(df)
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6
# 0 -0.002592  0.019907 -0.017646
# 1 -0.039493 -0.068332 -0.092204
# 2 -0.002592  0.002861 -0.025930
# 3  0.034309  0.022688 -0.009362
# 4 -0.002592 -0.031988 -0.046641

# %%
regressor = KNeighborsRegressor()
X = diabetes.data
y = diabetes.target

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42)

# %%
regressor.n_neighbors = 3
regressor.fit(X_train, y_train).score(X_test, y_test)
# Out:
# 0.36498737331014663

# %%
regressor.n_neighbors = 5
regressor.fit(X_train, y_train).score(X_test, y_test)
# Out:
# 0.43016439526042805

# %%
regressor.n_neighbors = 7
regressor.fit(X_train, y_train).score(X_test, y_test)
# Out:
# 0.436223206221125

# %%
regressor.n_neighbors = 20
regressor.fit(X_train, y_train).score(X_test, y_test)
# Out:
# 0.42402331475747657

# %%
regressor.n_neighbors = 25
regressor.fit(X_train, y_train).score(X_test, y_test)
# Out:
# 0.4373676398931915

# %% [markdown]
# ## Regresão Linear
#
# Na regressão linear, os "pesos" ou coeficientes são valores que multiplicam as variáveis independentes (também conhecidas como recursos ou atributos) para prever a variável dependente (a variável alvo).
#
# Em uma equação de regressão linear simples, você tem a seguinte relação: $y = w \cdot x + b$
#
# - $y$ é a variável dependente que você está tentando prever.
# - $x$ é a variável independente (recurso ou atributo).
# - $w$ é o peso ou coeficiente associado à variável independente $x$.
# - $b$ é o termo de viés (interceptação) que ajusta a linha para melhor se ajustar aos dados.
#
# > ## Aqui estão alguns pontos-chave sobre as variáveis independentes:
# > **Variável Dependente:** A variável que você está tentando prever ou explicar é chamada de variável dependente. Ela é afetada pelas variáveis independentes. <br><br>
# > **Variáveis Independentes:** Essas são as variáveis que você usa para fazer previsões ou explicar o comportamento da variável dependente. Elas são consideradas como tendo um efeito sobre a variável dependente. <br><br>
# > **Tipos de Variáveis Independentes:** As variáveis independentes podem ser de diferentes tipos, incluindo variáveis contínuas (números reais), variáveis categóricas (categorias), variáveis binárias (apenas dois valores possíveis), etc. <br><br>
# > **Função de Regressão:** Em modelos de regressão, as variáveis independentes são usadas para estimar os coeficientes (pesos) que descrevem a relação entre elas e a variável dependente. A função de regressão é uma equação que usa esses coeficientes para fazer previsões. <br><br>
# > **Análise de Regressão:** A análise de regressão é uma técnica estatística que é frequentemente usada para entender a relação entre as variáveis independentes e a variável dependente. Ela ajuda a quantificar o impacto das variáveis independentes sobre a variável dependente.

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lr.score(X_test, y_test)
# Out:
# 0.4526027629719196

# %%
# Interpretação mais detalhada do modelo de regressão treinado

pesos = pd.DataFrame({'Variavel': diabetes.feature_names, 'Coeficiente': lr.coef_})
print(pesos)
# Out:
#   Variavel  Coeficiente
# 0      age    37.904021
# 1      sex  -241.964362
# 2      bmi   542.428759
# 3       bp   347.703844
# 4       s1  -931.488846
# 5       s2   518.062277
# 6       s3   163.419983
# 7       s4   275.317902
# 8       s5   736.198859
# 9       s6    48.670657

# %% [markdown]
# ## Prever Resultados

# %%
y_pred = lr.predict(X_test)

# %%
# Gráfico de resíduos (diferença entre a predição e o valor verdadeiro esperado)

import matplotlib.pyplot as plt
plt.figure(figsize = (15,4))
plt.scatter(y_pred, y_test - y_pred)
plt.title("Gráfico de resíduos")
plt.xlabel("Valor previsto")
plt.ylabel("Resíduos")
plt.show()

# %%
plt.figure(figsize = (10,4))
plt.hist(y_test-y_pred, bins = 11)
plt.title("Histograma de resíduos")
plt.show()

# %% [markdown]
# #### Gráfico QQ
#
# Progressões mais elevadas não estão sendo capturadas pelo modelo de regressão linear. <br>
# Está errando mais quando ele prevê uma evolução alta do diabetes

# %%
from statsmodels.graphics.gofplots import qqplot_2samples

qqplot_2samples(y_test, y_pred, line = '45')
plt.title("Gráfico QQ")
plt.xlabel("Quantis de valores observados")
plt.ylabel("Quantis de valores previstos")
plt.show()
